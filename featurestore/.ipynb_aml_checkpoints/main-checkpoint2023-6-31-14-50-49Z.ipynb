# %%
print(f"spark version:{spark.version}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(f"spark version:{spark.version}")
#
# NameError: name 'spark' is not defined

# %%
import os
import json
import pandas as pd
from datetime import datetime

from azure.ai.ml.entities import FeatureSetSpecification,RecurrenceTrigger

import sys

root_dir = "./Users/ezzatdemnati/e2e_mlops_process"
sys.path.insert(0,root_dir)

import featurestore.setup.featurestore_setuptools as fs_setup

create_featurestore=False #True
create_feature_sets=False #True
Register_feature_sets_and_entities=False #True
set_offline_store=False #True
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 80, 6, Finished, Available)

# %%
# Read config file:
with open(os.path.join(root_dir,"featurestore/config/feature_store_config.json"),'r') as f:
    fs_config = json.load(f)

# Init FeatureStore class
fs_class = fs_setup.FeatureStoreTools(subscription_id=fs_config["subscription_id"],
                resource_group_name=fs_config["resource_group_name"],
                location=fs_config["location"],
                featurestore_name=fs_config["name"],
                root_dir=root_dir,
                fs_config=fs_config,
                ml_client=None
            )
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 80, 7, Finished, Available)
# root_dir:./Users/ezzatdemnati/e2e_mlops_process
# self.root_dir:./Users/ezzatdemnati/e2e_mlops_process/featurestore

# %%
# Create FeatureStore
if create_featurestore:        
    fs_class.create_feature_store(ml_client=None,verbose=0)
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 66, 11, Finished, Available)

# %%
# Get FeatureStore
feature_store = fs_class.get_feature_store(verbose=0)
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 78, 9, Finished, Available)
# Class FeatureStoreClient: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Method feature_stores: This is an experimental method, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# Class MaterializationStore: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
# Create Feature Sets
if create_feature_sets:
    # Create Feature Sets
    for fs_set in fs_config["feature_sets"]:
        print(fs_set)
        fs_class.create_feature_set(name=fs_set["name"],
            transformer_class_name=fs_set.get("transformer_class_name"), 
            data_source_path=fs_set["data_source_path"],
            timestamp_column_name=fs_set.get("timestamp_column_name"),
            source_delay=fs_set.get("source_delay"),
            index_columns=fs_set["index_columns"],
            source_lookback=fs_set.get("source_lookback"),
            temporal_join_lookback=fs_set.get("temporal_join_lookback"),
            infer_schema=fs_set["infer_schema"],
            export=True, # Export featuset specs locally
            verbose=1
            )
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 66, 13, Finished, Available)
# {'name': 'transactions', 'description': '', 'version': '4', 'tags': {'data_type': 'nonPII'}, 'stage': 'Development', 'entities': ['azureml:account:4'], 'transformation_code_path': '/featurestore/featuresets/transactions/transformation_code', 'data_source_path': 'wasbs://data@azuremlexampledata.blob.core.windows.net/feature-store-prp/datasources/transactions-source/*.parquet', 'timestamp_column_name': 'timestamp', 'source_delay': {'days': 0, 'hours': 0, 'minutes': 20}, 'transformer_class_name': 'transaction_transform.TransactionFeatureTransformer', 'index_columns': [{'name': 'accountID', 'type': 'STRING'}], 'source_lookback': {'days': 60, 'hours': 0, 'minutes': 0}, 'temporal_join_lookback': {'days': 60, 'hours': 0, 'minutes': 0}, 'infer_schema': True, 'offline': {'active': True, 'instance_type': 'standard_e8s_v3', 'spark_configuration': {'spark.driver.cores': 4, 'spark.driver.memory': '36g', 'spark.executor.cores': 4, 'spark.executor.memory': '36g', 'spark.executor.instances': 2}, 'schedule': {'interval': 3, 'frequency': 'Hour', 'start_time': '2023-04-15 00:04:10'}}}
# [Row(accountID='A1055520426191820', timestamp=datetime.datetime(2023, 1, 1, 19, 15, 53), transaction_3d_count=1, transaction_amount_3d_sum=133.28, transaction_amount_3d_avg=133.28, transaction_7d_count=1, transaction_amount_7d_sum=133.28, transaction_amount_7d_avg=133.28),
#  Row(accountID='A1055520426191820', timestamp=datetime.datetime(2023, 1, 12, 0, 4, 10), transaction_3d_count=1, transaction_amount_3d_sum=543.66, transaction_amount_3d_avg=543.66, transaction_7d_count=1, transaction_amount_7d_sum=543.66, transaction_amount_7d_avg=543.66),
#  Row(accountID='A1055520426719380', timestamp=datetime.datetime(2023, 4, 17, 21, 42, 9), transaction_3d_count=1, transaction_amount_3d_sum=217.09, transaction_amount_3d_avg=217.09, transaction_7d_count=1, transaction_amount_7d_sum=217.09, transaction_amount_7d_avg=217.09),
#  Row(accountID='A1055520426806680', timestamp=datetime.datetime(2023, 4, 8, 14, 43, 9), transaction_3d_count=1, transaction_amount_3d_sum=923.98, transaction_amount_3d_avg=923.98, transaction_7d_count=1, transaction_amount_7d_sum=923.98, transaction_amount_7d_avg=923.98),
#  Row(accountID='A1055520426936410', timestamp=datetime.datetime(2023, 3, 27, 3, 40, 54), transaction_3d_count=1, transaction_amount_3d_sum=139.99, transaction_amount_3d_avg=139.99, transaction_7d_count=1, transaction_amount_7d_sum=139.99, transaction_amount_7d_avg=139.99)]
# {'name': 'accounts', 'description': 'This entity represents user account index key accountID.', 'version': '4', 'tags': {'data_type': 'nonPII'}, 'stage': 'Development', 'entities': ['azureml:account:4'], 'data_source_path': 'wasbs://data@azuremlexampledata.blob.core.windows.net/feature-store-prp/datasources/accounts-precalculated/*.parquet', 'timestamp_column_name': 'timestamp', 'index_columns': [{'name': 'accountID', 'type': 'STRING'}], 'temporal_join_lookback': {'days': 365, 'hours': 0, 'minutes': 0}, 'infer_schema': True}
# [Row(accountID='A1055520426185580', timestamp=datetime.datetime(2021, 12, 31, 0, 0), accountCountry='GB', isUserRegistered=True, numPaymentRejects1dPerUser=0.0, accountAge=2000.0),
#  Row(accountID='A1055520426191820', timestamp=datetime.datetime(2021, 12, 31, 0, 0), accountCountry='US', isUserRegistered=True, numPaymentRejects1dPerUser=0.0, accountAge=1.0),
#  Row(accountID='A1055520426549020', timestamp=datetime.datetime(2021, 12, 31, 0, 0), accountCountry='AU', isUserRegistered=True, numPaymentRejects1dPerUser=0.0, accountAge=1.0),
#  Row(accountID='A1055520426719380', timestamp=datetime.datetime(2021, 12, 31, 0, 0), accountCountry='US', isUserRegistered=True, numPaymentRejects1dPerUser=0.0, accountAge=2000.0),
#  Row(accountID='A1055520426806680', timestamp=datetime.datetime(2021, 12, 31, 0, 0), accountCountry='GB', isUserRegistered=True, numPaymentRejects1dPerUser=1.0, accountAge=2000.0)]

# %%
# Register Feature Sets and Entities 
if Register_feature_sets_and_entities:
    # Register Entities 
    for fs_entity in fs_config["entities"]:
        fs_class.register_entity(name=fs_entity["name"],
            version=fs_entity["version"],
            index_columns=fs_entity["index_columns"],
            description=fs_entity["description"],
            tags=fs_entity["tags"]
        )
    
    # Register Feature Sets
    for fs_set in fs_config["feature_sets"]:
        spec_path = os.path.join(root_dir,f"featurestore/featuresets/{fs_set['name']}/spec")
        
        fs_class.register_feature_set(fs_set["name"], 
            version=fs_set["version"], 
            description=fs_set["description"], 
            entities=fs_set["entities"], 
            stage=fs_set["stage"], 
            specification=FeatureSetSpecification(path=spec_path), 
            tags=fs_set["tags"]
        )
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 66, 14, Finished, Available)
# Class DataColumn: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class FeatureStoreEntity: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Method feature_store_entities: This is an experimental method, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# Class FeatureSetSpecification: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class FeatureSet: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Method feature_sets: This is an experimental method, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class Feature: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# Uploading spec (0.0 MBs): 100%|██████████| 894/894 [00:00<00:00, 7004.17it/s]
#
#
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# description: This entity represents user account index key accountID.
# index_columns:
# - name: accountID
#   type: string
# name: account
# properties: {}
# stage: Development
# tags:
#   data_type: nonPII
# version: '4'
#
# Readonly attribute name will be ignored in class <class 'azure.ai.ml._restclient.v2023_02_01_preview.models._models_py3.FeaturesetVersion'>
# description: ''
# entities:
# - azureml:account:4
# name: transactions
# specification:
#   path: azureml://subscriptions/e0d7a68e-191f-4f51-83ce-d93995cd5c09/resourcegroups/my_ml_tests/workspaces/my-featurestore-e2e-test2/datastores/workspaceblobstore/paths/LocalUpload/48db643c599ec265301443435ed5583a/spec
# stage: Development
# tags:
#   data_type: nonPII
# version: '4'
#
# Readonly attribute name will be ignored in class <class 'azure.ai.ml._restclient.v2023_02_01_preview.models._models_py3.FeaturesetVersion'>
# description: This entity represents user account index key accountID.
# entities:
# - azureml:account:4
# name: accounts
# specification:
#   path: azureml://subscriptions/e0d7a68e-191f-4f51-83ce-d93995cd5c09/resourcegroups/my_ml_tests/workspaces/my-featurestore-e2e-test2/datastores/workspaceblobstore/paths/LocalUpload/fa46427c9d7e30ebbd5b8cee0ddd3ef2/spec
# stage: Development
# tags:
#   data_type: nonPII
# version: '4'

# %%
# Set Offline Materialization
if set_offline_store:
    storage_subscription_id = "e0d7a68e-191f-4f51-83ce-d93995cd5c09"
    storage_resource_group_name = "my_ml_tests"
    storage_account_name = "ezmylake"
    storage_file_system_name = "fsofflinetest"
    uai_name = "fstoreuaitest"

    gen2_container_arm_id = f"/subscriptions/{storage_subscription_id}/resourceGroups/{storage_resource_group_name}/providers/Microsoft.Storage/storageAccounts/{storage_account_name}/blobServices/default/containers/{storage_file_system_name}"

    # Set FeatureStore Offline materialization
    fs_class.set_feature_store_materialization(gen2_container_arm_id,storage_account_name,uai_name)

    # Set and run Feature Sets Offline materialization
    # create a schedule that runs the materialization job every 3 hours
    # Example: datetime(2023, 4, 15, 0, 4, 10, 0) = "2023-04-15 00:04:10"

    # Default offline config
    default_schedule = None
    default_spark_configuration = None
    if fs_config.get("offline_default"):
        if fs_config["offline_default"].get("schedule"):
            default_schedule = RecurrenceTrigger(
                interval=fs_config["offline_default"]["schedule"]["interval"], 
                frequency=fs_config["offline_default"]["schedule"]["frequency"], 
                start_time=datetime.fromisoformat(fs_config["offline_default"]["schedule"]["start_time"]) 
            )
            default_spark_configuration={
                        "spark.driver.cores": fs_config["offline_default"]["spark_configuration"]["spark.driver.cores"],
                        "spark.driver.memory": fs_config["offline_default"]["spark_configuration"]["spark.driver.memory"],
                        "spark.executor.cores": fs_config["offline_default"]["spark_configuration"]["spark.executor.cores"],
                        "spark.executor.memory": fs_config["offline_default"]["spark_configuration"]["spark.executor.memory"],
                        "spark.executor.instances": fs_config["offline_default"]["spark_configuration"]["spark.executor.instances"],
                    }
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 46, 19, Finished, Available)
# creating new user assigned managed identity
# managed identity 'fstoreuaitest' created successfully.
# Storage RBAC already exists for managed identity '67f1be8a-364c-4aef-9832-e436e1bf5253'.
# feature store RBAC already exists for managed identity '67f1be8a-364c-4aef-9832-e436e1bf5253'.
# Readonly attribute principal_id will be ignored in class <class 'azure.ai.ml._restclient.v2022_05_01.models._models_py3.UserAssignedIdentity'>
# Readonly attribute client_id will be ignored in class <class 'azure.ai.ml._restclient.v2022_05_01.models._models_py3.UserAssignedIdentity'>
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# Class FeatureStore: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ComputeRuntime: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class FeatureStoreSettings: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# Class WorkspaceConnection: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# /tmp/ipykernel_27991/340395219.py in <module>
#      10
#      11     # Set FeatureStore Offline materialization
# ---> 12     fs_class.set_feature_store_materialization(gen2_container_arm_id,storage_account_name,uai_name)
#      13
#      14     # Set and run Feature Sets Offline materialization
#
# /synfs/notebook/46/aml_notebook_mount/./Users/ezzatdemnati/e2e_mlops_process/featurestore/setup/featurestore_setuptools.py in set_feature_store_materialization(self, gen2_container_arm_id, storage_account_name, uai_name, verbose)
#     357         )
#     358
# --> 359         fs_poller = fs_client.feature_stores.begin_update(fs, update_dependent_resources=True)
#     360
#     361         print(fs_poller.result())
#
# ~/cluster-env/env/lib/python3.8/site-packages/azure/core/tracing/decorator.py in wrapper_use_tracer(*args, **kwargs)
#      74             span_impl_type = settings.tracing_implementation()
#      75             if span_impl_type is None:
# ---> 76                 return func(*args, **kwargs)
#      77
#      78             # Merge span is parameter is set, but only if no explicit parent are passed
#
# ~/cluster-env/env/lib/python3.8/site-packages/azure/ai/ml/_telemetry/activity.py in wrapper(*args, **kwargs)
#     261         def wrapper(*args, **kwargs):
#     262             with log_activity(logger, activity_name or f.__name__, activity_type, custom_dimensions):
# --> 263                 return f(*args, **kwargs)
#     264
#     265         return wrapper
#
# ~/cluster-env/env/lib/python3.8/site-packages/azure/ai/ml/operations/_feature_store_operations.py in begin_update(self, feature_store, update_dependent_resources, **kwargs)
#     356             return FeatureStore._from_rest_object(rest_obj=rest_obj)
#     357
# --> 358         return super().begin_update(
#     359             workspace=feature_store,
#     360             update_dependent_resources=update_dependent_resources,
#
# ~/cluster-env/env/lib/python3.8/site-packages/azure/ai/ml/operations/_workspace_operations_base.py in begin_update(self, workspace, update_dependent_resources, deserialize_callback, **kwargs)
#     252             )
#     253
# --> 254         poller = self._operation.begin_update(resource_group, workspace_name, update_param, polling=True, cls=callback)
#     255         return poller
#     256
#
# ~/cluster-env/env/lib/python3.8/site-packages/azure/core/tracing/decorator.py in wrapper_use_tracer(*args, **kwargs)
#      74             span_impl_type = settings.tracing_implementation()
#      75             if span_impl_type is None:
# ---> 76                 return func(*args, **kwargs)
#      77
#      78             # Merge span is parameter is set, but only if no explicit parent are passed
#
# ~/cluster-env/env/lib/python3.8/site-packages/azure/ai/ml/_restclient/v2023_04_01_preview/operations/_workspaces_operations.py in begin_update(self, resource_group_name, workspace_name, parameters, **kwargs)
#     983         cont_token = kwargs.pop('continuation_token', None)  # type: Optional[str]
#     984         if cont_token is None:
# --> 985             raw_result = self._update_initial(
#     986                 resource_group_name=resource_group_name,
#     987                 workspace_name=workspace_name,
#
# ~/cluster-env/env/lib/python3.8/site-packages/azure/ai/ml/_restclient/v2023_04_01_preview/operations/_workspaces_operations.py in _update_initial(self, resource_group_name, workspace_name, parameters, **kwargs)
#     930         if response.status_code not in [200, 202]:
#     931             map_error(status_code=response.status_code, response=response, error_map=error_map)
# --> 932             raise HttpResponseError(response=response, error_format=ARMErrorFormat)
#     933
#     934         deserialized = None
#
# HttpResponseError: (InvalidRequestContent) The request content contains duplicate JSON property names creating ambiguity in paths 'identity.userAssignedIdentities['/subscriptions/e0d7a68e-191f-4f51-83ce-d93995cd5c09/resourceGroups/my_ml_tests/providers/Microsoft.ManagedIdentity/userAssignedIdentities/fstoreuaitest']'. Please update the request content to eliminate duplicates and try again.
# Code: InvalidRequestContent
# Message: The request content contains duplicate JSON property names creating ambiguity in paths 'identity.userAssignedIdentities['/subscriptions/e0d7a68e-191f-4f51-83ce-d93995cd5c09/resourceGroups/my_ml_tests/providers/Microsoft.ManagedIdentity/userAssignedIdentities/fstoreuaitest']'. Please update the request content to eliminate duplicates and try again.

# %%
#Set offline materialization for all feature sets (if applicable)
for fs_set in fs_config["feature_sets"]:
    # Check if offline materialization config
    if fs_set.get("offline") and fs_set.get("offline").get("active"):
        # Check if schedule config
        feature_set_schedule = None
        spark_configuration = None

        #Check if feature set config is available
        if fs_set["offline"].get("instance_type") and fs_set["offline"].get("spark_configuration"):
            if fs_set["offline"].get("schedule"):
                feature_set_schedule = RecurrenceTrigger(
                    interval=fs_set["offline"]["schedule"]["interval"], 
                    frequency=fs_set["offline"]["schedule"]["frequency"], 
                    start_time=datetime.fromisoformat(fs_set["offline"]["schedule"]["start_time"]) 
                )                
                spark_configuration={
                    "spark.driver.cores": fs_set["offline"]["spark_configuration"]["spark.driver.cores"],
                    "spark.driver.memory": fs_set["offline"]["spark_configuration"]["spark.driver.memory"],
                    "spark.executor.cores": fs_set["offline"]["spark_configuration"]["spark.executor.cores"],
                    "spark.executor.memory": fs_set["offline"]["spark_configuration"]["spark.executor.memory"],
                    "spark.executor.instances": fs_set["offline"]["spark_configuration"]["spark.executor.instances"],
                }
            elif default_spark_configuration:
                feature_set_schedule = default_schedule
                spark_configuration = default_spark_configuration
            
        # Set feature set offline materialization
        if spark_configuration and feature_set_schedule:
            fs_class.set_feature_set_materialization(name=fs_set["name"],
                version=fs_set["version"],
                instance_type=fs_set["offline"]["instance_type"],
                spark_configuration=spark_configuration,
                schedule=feature_set_schedule
        )
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 66, 17, Finished, Available)
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# Readonly attribute name will be ignored in class <class 'azure.ai.ml._restclient.v2023_02_01_preview.models._models_py3.FeaturesetVersion'>
# description: ''
# entities:
# - azureml:account:4
# materialization_settings:
#   offline_enabled: true
#   online_enabled: false
#   resource:
#     instance_type: standard_e8s_v3
#   schedule:
#     frequency: hour
#     interval: 3
#     schedule:
#       hours: []
#       minutes: []
#     start_time: '2023-04-15 00:04:10'
#     time_zone: UTC
#     type: recurrence
#   spark_configuration:
#     spark.driver.cores: '4'
#     spark.driver.memory: 36g
#     spark.executor.cores: '4'
#     spark.executor.instances: '2'
#     spark.executor.memory: 36g
# name: transactions
# specification:
#   path: azureml://subscriptions/e0d7a68e-191f-4f51-83ce-d93995cd5c09/resourcegroups/my_ml_tests/workspaces/my-featurestore-e2e-test2/datastores/workspaceblobstore/paths/LocalUpload/48db643c599ec265301443435ed5583a/spec
# stage: Development
# tags:
#   data_type: nonPII
# version: '4'

# %% [markdown]
# ### Backfill data for the transactions feature set

# %%
job_id= fs_class.run_backfill(featureset_name="transactions",
                      featureset_version="4",
                      start_datetime="2023-01-01 00:00:00",
                      end_datetime="2023-06-30 23:59:00"
                     )

# get the job URL, and stream the job logs
fs_client.jobs.stream(job_id)
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 80, 10, Finished, Available)
# Datetime with no tzinfo will be considered UTC.
# Datetime with no tzinfo will be considered UTC.
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded

# %%
# look up the featureset by providing name and version
transactions_featureset = feature_store.feature_sets.get("transactions", "4")
df = transactions_featureset.to_spark_dataframe()

from pyspark.sql import functions

display(df.agg(functions.min('timestamp'),functions.max('timestamp')))
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 70, 15, Finished, Available)
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# FeatureSet: transactions, version: 4, was not materialized, please check offline store: /subscriptions/e0d7a68e-191f-4f51-83ce-d93995cd5c09/resourceGroups/my_ml_tests/providers/Microsoft.Storage/storageAccounts/ezmylake/blobServices/default/containers/fsofflinetest
# FeatureSet: transactions, version: 4 load data from source..
# SynapseWidget(Synapse.DataFrame, 1b2500ac-1e53-41e9-b93c-442ab580ebae)

# %% [markdown]
# ## Model Training

# %%
# get the registered transactions feature set, version 1
transactions_featureset = feature_store.feature_sets.get("transactions", "4")
accounts_featureset = feature_store.feature_sets.get("accounts", "4")


# Notice that account feature set spec is in your local dev environment (this notebook): not registered with feature store yet
features = [
    accounts_featureset.get_feature("accountAge"),
    accounts_featureset.get_feature("numPaymentRejects1dPerUser"),
    transactions_featureset.get_feature("transaction_amount_7d_sum"),
    transactions_featureset.get_feature("transaction_amount_3d_sum"),
    transactions_featureset.get_feature("transaction_amount_7d_avg"),
]
features
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 78, 10, Finished, Available)
# Method feature_sets: This is an experimental method, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# Method feature_store_entities: This is an experimental method, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# [Feature(Name=accountAge,Type=double),
#  Feature(Name=numPaymentRejects1dPerUser,Type=double),
#  Feature(Name=transaction_amount_7d_sum,Type=double),
#  Feature(Name=transaction_amount_3d_sum,Type=double),
#  Feature(Name=transaction_amount_7d_avg,Type=double)]

# %%
accounts_featureset = feature_store.feature_sets.get("accounts", "4")
# get access to the feature data
accounts_feature_df = accounts_featureset.to_spark_dataframe()
display(accounts_feature_df.head(5))
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 78, 11, Finished, Available)
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# FeatureSet: accounts, version: 4, does not have materialization settings..
# FeatureSet: accounts, version: 4 load data from source..
# SynapseWidget(Synapse.DataFrame, fdfa5aae-c221-4d4c-b170-b82b41239171)

# %%
transactions_featureset = feature_store.feature_sets.get("transactions", "4")

# get access to the feature data
transactions_featureset_df = transactions_featureset.to_spark_dataframe()
display(transactions_featureset_df.head(5))
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 78, 23, Finished, Available)
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
# FeatureSet: transactions, version: 4, was materialized, load data from offline store: /subscriptions/e0d7a68e-191f-4f51-83ce-d93995cd5c09/resourceGroups/my_ml_tests/providers/Microsoft.Storage/storageAccounts/ezmylake/blobServices/default/containers/fsofflinetest
# SynapseWidget(Synapse.DataFrame, 9c90ccd5-cace-43ab-8550-261215386da2)

# %%
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 78, 21, Finished, Available)

# %%
# List available feature sets
all_featuresets = feature_store.feature_sets.list()
for fs in all_featuresets:
    print(fs)

# List of versions for transactions feature set
print("=====================All versions=============================")
all_transactions_featureset_versions = feature_store.feature_sets.list(
    name="transactions"
)
v=0
for fs in all_transactions_featureset_versions:
    if int(fs.name)>v:
        v = int(fs.name)
    print(f"version:{fs.name}")

# See properties of the transactions featureset including list of features
print(f"=====================Current version {v}=============================")
for f in feature_store.feature_sets.get(name="transactions", version=str(v)).features:
    print(f"Feature \n    name:{f.name} \n    Type:{f.type} \n    Description:{f.description}")
# Out:
# StatementMeta(c25b756a-1f28-4821-94d2-7088ba2a2663, 66, 57, Finished, Available)
# description: ''
# entities: []
# name: accounts
# specification: {}
# stage: Development
# tags: {}
# version: ''
#
# description: ''
# entities: []
# name: transactions
# specification: {}
# stage: Development
# tags: {}
# version: ''
#
# =====================All versions=============================
# version:4
# version:3
# version:2
# version:1
# =====================Current version 4=============================
# Feature
#     name:transaction_3d_count
#     Type:long
#     Description:None
# Feature
#     name:transaction_amount_3d_sum
#     Type:double
#     Description:None
# Feature
#     name:transaction_amount_3d_avg
#     Type:double
#     Description:None
# Feature
#     name:transaction_7d_count
#     Type:long
#     Description:None
# Feature
#     name:transaction_amount_7d_sum
#     Type:double
#     Description:None
# Feature
#     name:transaction_amount_7d_avg
#     Type:double
#     Description:None
# _AzureMLSparkOnBehalfOfCredential.get_token succeeded
